# %%
import numpy as np
import pandas as pd

# %%
# pd.options.display.max_rows = 2

# %%
cavideos = pd.read_csv('CAvideos.csv')
devideos = pd.read_csv('DEvideos.csv')
frvideos = pd.read_csv('FRvideos.csv')
usvideos = pd.read_csv('USvideos.csv')
gbvideos = pd.read_csv('GBvideos.csv', on_bad_lines='skip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cavideos = pd.read_csv('CAvideos.csv')
#       2 devideos = pd.read_csv('DEvideos.csv')
#       3 frvideos = pd.read_csv('FRvideos.csv')
#
# ...

# %%
pd.concat([cavideos, devideos, frvideos, gbvideos, usvideos])
# pd.concat([cavideos, devideos, frvideos, gbvideos, usvideos], axis=1)
# Out:
#          video_id trending_date  \
# 0     n1WpP7iowLc      17.14.11
# 1     0dBIkQ4Mz1M      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     d380meD0W0M      17.14.11
# 4     2Vv-BfVoq4g      17.14.11
# ...           ...           ...
# 2195  88kkrRv1UgI      17.24.11
# 2196  dcipHnWcB0w      17.24.11
# 2197  wJh-jurxmGQ      17.24.11
# 2198  JLOFZoBJnd8      17.24.11
# 2199  16W7c0mb-rE      17.24.11
#
#                                                   title  \
# 0            Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                         PLUSH - Bad Unboxing Fan Mail
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                              I Dare You: GOING BALD!?
# 4           Ed Sheeran - Perfect (Official Music Video)
# ...                                                 ...
# 2195  What Happens to You if You Upload Your Mind to...
# 2196  Kim Kardashian's Surrogate Didn't Know Whose B...
# 2197  Will Ferrell Left Speechless as Mark Wahlberg ...
# ...

# %%
cacategory = pd.DataFrame(pd.read_json('CA_category_id.json'))
# cacategory

# %%
test = cacategory['items'][20]
test
# Out:
# {'kind': 'youtube#videoCategory',
#  'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/pUZOAC_s9sfiwar639qr_wAB-aI"',
#  'id': '34',
#  'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'title': 'Comedy',
#   'assignable': False}}

# %%
test['snippet']['title']
# Out:
# 'Comedy'

# %%
l1=[]
l2=[]
for i in cacategory['items']:

    key= f'{i['id']}'
    value1 = i['snippet']['title']
    value2 = i['snippet']['channelId']

    l1.append(int(key))
    l2.append([value1, value2])

data = dict(zip(l1,l2))
data
# Out:
# {1: ['Film & Animation', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  2: ['Autos & Vehicles', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  10: ['Music', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  15: ['Pets & Animals', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  17: ['Sports', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  18: ['Short Movies', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  19: ['Travel & Events', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  20: ['Gaming', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  21: ['Videoblogging', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  22: ['People & Blogs', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  23: ['Comedy', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  24: ['Entertainment', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  25: ['News & Politics', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  26: ['Howto & Style', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  27: ['Education', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  28: ['Science & Technology', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  30: ['Movies', 'UCBR8-60-B28hp2BmDPdntcQ'],
#  31: ['Anime/Animation', 'UCBR8-60-B28hp2BmDPdntcQ'],
# ...

# %%
rows = [(key, *value) for key, value in data.items()]
columns=['category_id', 'Category_name', 'channel_id']
cacategory_json = pd.DataFrame(rows, columns=columns)
cacategory_json
# Out:
#     category_id         Category_name                channel_id
# 0             1      Film & Animation  UCBR8-60-B28hp2BmDPdntcQ
# 1             2      Autos & Vehicles  UCBR8-60-B28hp2BmDPdntcQ
# 2            10                 Music  UCBR8-60-B28hp2BmDPdntcQ
# 3            15        Pets & Animals  UCBR8-60-B28hp2BmDPdntcQ
# 4            17                Sports  UCBR8-60-B28hp2BmDPdntcQ
# 5            18          Short Movies  UCBR8-60-B28hp2BmDPdntcQ
# 6            19       Travel & Events  UCBR8-60-B28hp2BmDPdntcQ
# 7            20                Gaming  UCBR8-60-B28hp2BmDPdntcQ
# 8            21         Videoblogging  UCBR8-60-B28hp2BmDPdntcQ
# 9            22        People & Blogs  UCBR8-60-B28hp2BmDPdntcQ
# 10           23                Comedy  UCBR8-60-B28hp2BmDPdntcQ
# 11           24         Entertainment  UCBR8-60-B28hp2BmDPdntcQ
# 12           25       News & Politics  UCBR8-60-B28hp2BmDPdntcQ
# 13           26         Howto & Style  UCBR8-60-B28hp2BmDPdntcQ
# ...

# %%
ca_merge = pd.merge(cavideos, cacategory_json, on='category_id', how='left')
ca_merge
# Out:
#          video_id trending_date  \
# 0     n1WpP7iowLc      17.14.11
# 1     0dBIkQ4Mz1M      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     d380meD0W0M      17.14.11
# 4     2Vv-BfVoq4g      17.14.11
# ...           ...           ...
# 2194  3fFBEPZeYY0      17.24.11
# 2195  qaZd--LEMyo      17.24.11
# 2196  Ja8sm19k0e0      17.24.11
# 2197  y_XvYHi42hs      17.24.11
# 2198  Ufqs0mxfqRI      17.24.11
#
#                                                   title   channel_title  \
# 0            Eminem - Walk On Water (Audio) ft. Beyoncé      EminemVEVO
# 1                         PLUSH - Bad Unboxing Fan Mail       iDubbbzTV
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...    Rudy Mancuso
# 3                              I Dare You: GOING BALD!?        nigahiga
# 4           Ed Sheeran - Perfect (Official Music Video)      Ed Sheeran
# ...                                                 ...             ...
# ...

# %%
# ca_merge[['category_id', 'Category_name']]

# %%
ca_merge.groupby(['category_id', 'Category_name'])['Category_name'].count()
# Out:
# category_id  Category_name
# 1            Film & Animation        107
# 2            Autos & Vehicles         26
# 10           Music                   201
# 15           Pets & Animals           18
# 17           Sports                  161
# 19           Travel & Events          23
# 20           Gaming                   60
# 22           People & Blogs          234
# 23           Comedy                  259
# 24           Entertainment           677
# 25           News & Politics         178
# 26           Howto & Style            95
# 27           Education                49
# 28           Science & Technology     96
# 43           Shows                    10
# Name: Category_name, dtype: int64

# %%
cacategory
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# 5   youtube#videoCategoryListResponse
# 6   youtube#videoCategoryListResponse
# 7   youtube#videoCategoryListResponse
# 8   youtube#videoCategoryListResponse
# 9   youtube#videoCategoryListResponse
# 10  youtube#videoCategoryListResponse
# 11  youtube#videoCategoryListResponse
# 12  youtube#videoCategoryListResponse
# 13  youtube#videoCategoryListResponse
# 14  youtube#videoCategoryListResponse
# 15  youtube#videoCategoryListResponse
# 16  youtube#videoCategoryListResponse
# 17  youtube#videoCategoryListResponse
# 18  youtube#videoCategoryListResponse
# 19  youtube#videoCategoryListResponse
# 20  youtube#videoCategoryListResponse
# 21  youtube#videoCategoryListResponse
# 22  youtube#videoCategoryListResponse
# ...

# %%
cavideos
# Out:
#          video_id trending_date  \
# 0     n1WpP7iowLc      17.14.11
# 1     0dBIkQ4Mz1M      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     d380meD0W0M      17.14.11
# 4     2Vv-BfVoq4g      17.14.11
# ...           ...           ...
# 2194  3fFBEPZeYY0      17.24.11
# 2195  qaZd--LEMyo      17.24.11
# 2196  Ja8sm19k0e0      17.24.11
# 2197  y_XvYHi42hs      17.24.11
# 2198  Ufqs0mxfqRI      17.24.11
#
#                                                   title   channel_title  \
# 0            Eminem - Walk On Water (Audio) ft. Beyoncé      EminemVEVO
# 1                         PLUSH - Bad Unboxing Fan Mail       iDubbbzTV
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...    Rudy Mancuso
# 3                              I Dare You: GOING BALD!?        nigahiga
# 4           Ed Sheeran - Perfect (Official Music Video)      Ed Sheeran
# ...                                                 ...             ...
# ...

# %%
ca_merge
# Out:
#          video_id trending_date  \
# 0     n1WpP7iowLc      17.14.11
# 1     0dBIkQ4Mz1M      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     d380meD0W0M      17.14.11
# 4     2Vv-BfVoq4g      17.14.11
# ...           ...           ...
# 2194  3fFBEPZeYY0      17.24.11
# 2195  qaZd--LEMyo      17.24.11
# 2196  Ja8sm19k0e0      17.24.11
# 2197  y_XvYHi42hs      17.24.11
# 2198  Ufqs0mxfqRI      17.24.11
#
#                                                   title   channel_title  \
# 0            Eminem - Walk On Water (Audio) ft. Beyoncé      EminemVEVO
# 1                         PLUSH - Bad Unboxing Fan Mail       iDubbbzTV
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...    Rudy Mancuso
# 3                              I Dare You: GOING BALD!?        nigahiga
# 4           Ed Sheeran - Perfect (Official Music Video)      Ed Sheeran
# ...                                                 ...             ...
# ...

# %%
ca_merge["Category_name"].value_counts()
# Out:
# Category_name
# Entertainment           677
# Comedy                  259
# People & Blogs          234
# Music                   201
# News & Politics         178
# Sports                  161
# Film & Animation        107
# Science & Technology     96
# Howto & Style            95
# Gaming                   60
# Education                49
# Autos & Vehicles         26
# Travel & Events          23
# Pets & Animals           18
# Shows                    10
# Name: count, dtype: int64

# %%
ca_merge.groupby(['category_id','Category_name'])[['views', 'likes','dislikes','comment_count']].sum().sort_values('likes').reset_index()
# Out:
#     category_id         Category_name      views     likes  dislikes  \
# 0            43                 Shows    5251737     55110      6899
# 1            19       Travel & Events    6251520    158730      3488
# 2             2      Autos & Vehicles   11869841    400182      9633
# 3            15        Pets & Animals   11406445    741790     12639
# 4            25       News & Politics   38803885    910695     79890
# 5            27             Education   21363464    939354     32822
# 6            20                Gaming   24913003   1266504     22698
# 7            26         Howto & Style   73263647   2324907     53707
# 8            17                Sports  139951839   3123326     95657
# 9            28  Science & Technology  140592281   3850209    302422
# 10           22        People & Blogs  147077542   5204401    898888
# 11            1      Film & Animation  249009422   5251653    158827
# 12           23                Comedy  254712594  13366283    383083
# ...
